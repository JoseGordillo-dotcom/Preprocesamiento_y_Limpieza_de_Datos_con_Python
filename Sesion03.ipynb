# %% [markdown]
# # Preprocesamiento de Datos con Python
# ## FES Aragón
# ### ICO
# #### José Rodolfo Juan Gordillo Negrete

# %%
import pandas as pd

# %%
#url = 'https://es.wikipedia.org/wiki/ISO_3166-2:US'
url = 'https://es.wikipedia.org/wiki/Premier_League_2021-22'
df_html = pd.read_html(url)
print(type(df_html))
print("Numero de tablas en DF", len(df_html))
df_html
# Out:
# <class 'list'>
# Numero de tablas en DF 78
# [                               Premier League 2021-22  \
#  0   El Brentford Community Stadium alberga partido...
#  1                                     Datos generales
#  2                                                Sede
#  3                                          Asociación
#  4                                           Categoría
#  5                                               Fecha
#  6                                             Edición
#  7                                          TV oficial
#  8                                            Palmarés
#  9                                         Def. título
#  10                                            Campeón
#  11                                         Subcampeón
#  12                                            Tercero
#  13                                      Mejor jugador
#  14                                      Mejor portero
# ...

# %%
print(type(df_html[0]))
df_html[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                Premier League 2021-22  \
# 0   El Brentford Community Stadium alberga partido...
# 1                                     Datos generales
# 2                                                Sede
# 3                                          Asociación
# 4                                           Categoría
# 5                                               Fecha
# 6                                             Edición
# 7                                          TV oficial
# 8                                            Palmarés
# 9                                         Def. título
# 10                                            Campeón
# 11                                         Subcampeón
# 12                                            Tercero
# 13                                      Mejor jugador
# 14                                      Mejor portero
# 15                                 Datos estadísticos
# ...

# %%
df_html[6]
# Out:
#                      Equipo           Ciudad  \
# 0                   Arsenal          Londres
# 1               Aston Villa       Birmingham
# 2                 Brentford          Londres
# 3    Brighton & Hove Albion  Brighton & Hove
# 4                   Burnley          Burnley
# 5                   Chelsea          Londres
# 6            Crystal Palace          Londres
# 7                   Everton        Liverpool
# 8              Leeds United            Leeds
# 9            Leicester City        Leicester
# 10                Liverpool        Liverpool
# 11          Manchester City       Mánchester
# 12        Manchester United       Mánchester
# 13         Newcastle United        Newcastle
# 14             Norwich City          Norwich
# 15              Southampton      Southampton
# 16        Tottenham Hotspur          Londres
# 17                  Watford          Watford
# 18          West Ham United          Londres
# 19  Wolverhampton Wanderers    Wolverhampton
#
# ...

# %%
df_html[8]
# Out:
#                      Equipo               Entrenador (Jornadas)  \
# 0   Wolverhampton Wanderers  Nuno Espírito Santo (Pretemporada)
# 1                   Everton      Carlo Ancelotti (Pretemporada)
# 2         Tottenham Hotspur       Ryan Mason INT (Pretemporada)
# 3            Crystal Palace          Roy Hodgson (Pretemporada)
# 4                   Watford                 Xisco Muñoz (1 - 7)
# 5          Newcastle United                 Steve Bruce (1 - 8)
# 6         Tottenham Hotspur        Nuno Espírito Santo (1 - 10)
# 7              Norwich City               Daniel Farke (1 - 11)
# 8               Aston Villa                 Dean Smith (1 - 11)
# 9          Newcastle United           Graeme Jones INT (9 - 11)
# 10        Manchester United        Ole Gunnar Solskjær (1 - 12)
# 11        Manchester United         Michael Carrick INT (13-14)
# 12                  Everton               Rafa Benítez (1 - 22)
# 13                  Watford            Claudio Ranieri (8 - 23)
# ...

# %%
i = 0
for dfh in df_html:
    print(str(i).center(60,"*"))
    dfh.info()
    i = i + 1
# Out:
# *****************************0******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
# Premier League 2021-22      32 non-null object
# Premier League 2021-22.1    32 non-null object
# Premier League 2021-22.2    29 non-null object
# dtypes: object(3)
# memory usage: 896.0+ bytes
# *****************************1******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# 0    3 non-null object
# 1    3 non-null object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************2******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
# 0    1 non-null object
# 1    1 non-null object
# 2    1 non-null object
# dtypes: object(3)
# memory usage: 152.0+ bytes
# *****************************3******************************
# ...

# %%
from sqlalchemy import create_engine

us='fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegio02'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd,url,puerto,bd,auth)
str_conn
# Out:
# 'mysql+mysqlconnector://fesalu:bdfes2023@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password'

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * from alumnos WHERE sexo = %s'''
df_mysql = pd.read_sql_query(sql=sql, con=conn, params=['F'])

# %%
df_mysql
# Out:
#     clave_alu clave_admin ap_paterno ap_materno             nombre sexo  \
# 0    11030172        4812   BORBOLLA      RAMOS            ARGELIA    F
# 1    11030173        4849     CASTRO    MANCERA      KARLA MARIANA    F
# 2    11030207        4808    AGUILAR  ZAMARRIPA    MICHELLE IVONNE    F
# 3    11030218        4717     FLORES      NAMUR     MARIA FERNANDA    F
# 4    11030254        4724   GONZALEZ       DIAZ  CLAUDIA ALEJANDRA    F
# ..        ...         ...        ...        ...                ...  ...
# 278  11080201                   SOTO      ELIAS     PALOMA DENISSE    F
# 279  11080202                 VALLES      RAMOS            MARIANA    F
# 280  11080205                  BADUY     VALDEZ      KENNIA ASENET    F
# 281  11080208               BECERRIL     HUERTA            MARIANA    F
# 282  11080209        NULL    MORALES    CARMONA      KARLA MARIANA    F
#
#                    curp  peso  estatura                           direccion  \
# ...
